# %% [markdown]
# # The Hello World  Deep Learning

# %% [markdown]
# As with every learning topic, we start with something very simple.
#
# In this case we will make a comparison of a program declaring rules and another that will generate the rules according to the input.
#
#
# ```
# float function(float x){
#     float y = (2 * x) - 1; #rule
#     return y;
# }
# ```
#
# With deep neural networks we could make a model which can trigger a function very similar to the previous one.

# %% [markdown]
# ## Imports
#
# Typically we start by importing libraries, in this case we will use the google [TensorFlow](https://www.tensorflow.org/) API we will call it as tf, we will also use [Keras](https://keras.io/) for the design of the layers and finally we will use [NumPy](https://numpy.org/) for the handling of arrays

# %% [markdown]
# ## Define and Compile the Neural Network
#
# Next we will create the simplest possible neural network. It has 1 layer, and that layer has 1 neuron, and the input shape to it is just 1 value.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([
                             keras.layers.Dense(units=1, input_shape=[1])
                             ])

# %% [markdown]
# Now we compile our Neural Network. When we do so, we have to specify 2 functions, a loss and an optimizer.
#
# We know that in our function, the relationship between the numbers is y=2x-1.
#
# When the computer is trying to 'learn' that, it makes a guess y=10x+10. The LOSS function measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses the OPTIMIZER function to make another guess. Based on how the loss function went, it will try to minimize the loss. At that point maybe it will come up with somehting like y=5x+5, which, while still pretty bad, is closer to the correct result (i.e. the loss is lower)
#
# It will repeat this for the number of EPOCHS which you will see shortly. But first, here's how we tell it to use 'MEAN SQUARED ERROR' for the loss and 'STOCHASTIC GRADIENT DESCENT' for the optimizer.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# in the above code snippet we used the optimized stochastic descending gradient "sgd"

# %% [markdown]
# ## Providing the Data
#
# Next up we'll feed in some data. In this case we are taking 6 xs and 6ys. You can see that the relationship between these is that y=2x-1, so where x = -1, y=-3.

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Training the Neural Network

# %% [markdown]
# The process of training the neural network, where it 'learns' the relationship between the Xs and Ys is in the **model.fit**  call. This is where it will go through the loop we spoke about above, making a guess, measuring how good or bad it is (aka the loss), using the opimizer to make another guess etc. It will do it for the number of epochs you specify. When you run this code, you'll see the loss on the right hand side.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 963us/step - loss: 6.2199
# Epoch 2/500
# 1/1 [==============================] - 0s 742us/step - loss: 5.0781
# Epoch 3/500
# 1/1 [==============================] - 0s 605us/step - loss: 4.1759
# Epoch 4/500
# 1/1 [==============================] - 0s 642us/step - loss: 3.4624
# Epoch 5/500
# 1/1 [==============================] - 0s 495us/step - loss: 2.8975
# Epoch 6/500
# 1/1 [==============================] - 0s 597us/step - loss: 2.4494
# Epoch 7/500
# 1/1 [==============================] - 0s 609us/step - loss: 2.0934
# Epoch 8/500
# 1/1 [==============================] - 0s 579us/step - loss: 1.8099
# Epoch 9/500
# 1/1 [==============================] - 0s 736us/step - loss: 1.5835
# Epoch 10/500
# 1/1 [==============================] - 0s 605us/step - loss: 1.4021
# Epoch 11/500
# 1/1 [==============================] - 0s 488us/step - loss: 1.2562
# Epoch 12/500
# ...

# %% [markdown]
# Now we have a model that has been trained to learn the relationship between X and Y. You can use the model.predict method to make it discover the Y of a previously unknown X. So, for example, if X = 10, what do you think Y will be?

# %%
print(model.predict([10.0]))
# Out:
# [[18.983904]]

# %% [markdown]
# Remember that neural networks deal with probabilities, so given the data that we fed the NN with, it calculated that there is a very high probability that the relationship between X and Y is Y=2X-1, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 19, but not necessarily 19.
